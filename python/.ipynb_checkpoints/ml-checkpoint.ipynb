# %%
import sys

# !$sys.executable -m pip install tensorflow

import tensorflow as tf
print("TensorFlow version:", tf.__version__)

from tensorflow.keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras import Model


print("dies")
# Out:
# Requirement already satisfied: tensorflow in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (2.10.0)
# Collecting libclang>=13.0.0
#   Using cached libclang-15.0.6.1-py2.py3-none-macosx_10_9_x86_64.whl (25.0 MB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp38-cp38-macosx_10_9_x86_64.whl (980 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 980.4/980.4 kB 6.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: numpy>=1.20 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.30.0-cp38-cp38-macosx_10_14_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: flatbuffers>=2.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (22.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.35.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.6.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (4.11.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Installing collected packages: libclang, tensorflow-io-gcs-filesystem, protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed libclang-15.0.6.1 protobuf-3.19.6 tensorflow-io-gcs-filesystem-0.30.0
# 2023-02-11 22:05:27.744610: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorFlow version: 2.10.0
# dies

# %%
import pandas as pd

# !$sys.executable -m pip install scikit-learn
# !$sys.executable -m pip install keras

from sklearn import preprocessing

df = pd.read_csv('housepricedata.csv')
dataset = df.values

X = dataset[:,0:10]
Y = dataset[:,10]


min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
# Out:
# Requirement already satisfied: scikit-learn in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: keras in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (2.10.0)

# %%
#Kot: added some imports
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import regularizers

model_3 = Sequential([
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(10,)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)),
])

model_3.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

hist_3 = model_3.fit(X, Y,
          batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 2023-02-11 22:13:05.573641: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 46/46 [==============================] - 1s 8ms/step - loss: 137.0384 - accuracy: 0.4986
# Epoch 2/100
# 46/46 [==============================] - 0s 7ms/step - loss: 32.0828 - accuracy: 0.4904
# Epoch 3/100
# 46/46 [==============================] - 0s 7ms/step - loss: 28.1163 - accuracy: 0.5144
# Epoch 4/100
# 46/46 [==============================] - 0s 7ms/step - loss: 24.9450 - accuracy: 0.4863
# Epoch 5/100
# 46/46 [==============================] - 0s 7ms/step - loss: 23.5681 - accuracy: 0.5295
# Epoch 6/100
# 46/46 [==============================] - 0s 7ms/step - loss: 21.8180 - accuracy: 0.5021
# Epoch 7/100
# 46/46 [==============================] - 0s 7ms/step - loss: 20.5747 - accuracy: 0.5205
# Epoch 8/100
# 46/46 [==============================] - 0s 7ms/step - loss: 19.7888 - accuracy: 0.5308
# Epoch 9/100
# 46/46 [==============================] - 0s 7ms/step - loss: 19.2084 - accuracy: 0.5295
# Epoch 10/100
# 46/46 [==============================] - 0s 7ms/step - loss: 18.7305 - accuracy: 0.5116
# Epoch 11/100
# 46/46 [==============================] - 0s 8ms/step - loss: 18.2636 - accuracy: 0.5110
# Epoch 12/100
# 46/46 [==============================] - 0s 7ms/step - loss: 17.7803 - accuracy: 0.5137
# Epoch 13/100
# 46/46 [==============================] - 0s 7ms/step - loss: 17.3426 - accuracy: 0.5233
# Epoch 14/100
# 46/46 [==============================] - 0s 7ms/step - loss: 16.9343 - accuracy: 0.5068
# Epoch 15/100
# 46/46 [==============================] - 0s 7ms/step - loss: 16.5173 - accuracy: 0.5096
# Epoch 16/100
# 46/46 [==============================] - 0s 8ms/step - loss: 16.1195 - accuracy: 0.5089
100
# 46/46 [==============================] - 0s 7ms/step - loss: 3.4987 - accuracy: 0.5041
# Epoch 78/100
# 46/46 [==============================] - 0s 8ms/step - loss: 3.3977 - accuracy: 0.5123
# Epoch 79/100
# 46/46 [==============================] - 0s 7ms/step - loss: 3.3165 - accuracy: 0.5068
# Epoch 80/100
# 46/46 [==============================] - 0s 7ms/step - loss: 3.2271 - accuracy: 0.5021
# Epoch 81/100
# 46/46 [==============================] - 0s 7ms/step - loss: 3.1522 - accuracy: 0.5137
# Epoch 82/100
# 46/46 [==============================] - 0s 7ms/step - loss: 3.0727 - accuracy: 0.5021
# Epoch 83/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.9867 - accuracy: 0.4973
# Epoch 84/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.8975 - accuracy: 0.5247
# Epoch 85/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.8268 - accuracy: 0.5068
# Epoch 86/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.7522 - accuracy: 0.5089
# Epoch 87/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.6870 - accuracy: 0.4877
# Epoch 88/100
# 46/46 [==============================] - 0s 8ms/step - loss: 2.6102 - accuracy: 0.5281
# Epoch 89/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.5686 - accuracy: 0.5110
# Epoch 90/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.4980 - accuracy: 0.5096
# Epoch 91/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.4370 - accuracy: 0.5123
# Epoch 92/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.3791 - accuracy: 0.5082
# Epoch 93/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.3179 - accuracy: 0.5014
# Epoch 94/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.2488 - accuracy: 0.5062
# Epoch 95/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.1861 - accuracy: 0.5027
# Epoch 96/100
# 46/46 [==============================] - 0s 8ms/step - loss: 2.1279 - accuracy: 0.5301
# Epoch 97/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.0766 - accuracy: 0.5000
# Epoch 98/100
# 46/46 [==============================] - 0s 7ms/step - loss: 2.0204 - accuracy: 0.5007
# Epoch 99/100
# 46/46 [==============================] - 0s 7ms/step - loss: 1.9652 - accuracy: 0.4973
# Epoch 100/100
# 46/46 [==============================] - 0s 7ms/step - loss: 1.9229 - accuracy: 0.4993

# %%
#Kot: Already installed it at the top

pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (2.10.0)
# Requirement already satisfied: numpy>=1.20 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: packaging in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (22.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: setuptools in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: h5py>=2.9.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (0.30.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.35.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.2.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (4.11.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
test_input = dataset[:,0:1]
print(test_input)

yhat = model_3.predict(test_input)

#print(yhat)
# Out:
# [8450    7    5  856    2    1    3    8    0  548    1]
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[23], line 4
#       1 test_input = dataset[0]
#       2 print(test_input)
# ----> 4 yhat = model_3.predict(test_input)
#
# File ~/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sequential/dense_2/Relu' defined at (most recent call last):
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/traitlets/config/application.py", line 992, in launch_instance
#       app.start()
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 711, in start
#       self.io_loop.start()
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#       self._run_once()
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#       handle._run()
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/asyncio/events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#       res = shell.run_cell(
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2945, in run_cell
#       result = self._run_cell(
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3000, in _run_cell
#       return runner(coro)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3203, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3382, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3442, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/xv/lq55twps01zb24tdhw5vb32w0000gn/T/ipykernel_36588/735480249.py", line 4, in <module>
#       yhat = model_3.predict(test_input)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/engine/training.py", line 2253, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/engine/training.py", line 2041, in predict_function
#       return step_function(self, iterator)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/engine/training.py", line 2027, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/engine/training.py", line 2015, in run_step
#       outputs = model.predict_step(data)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/engine/training.py", line 1983, in predict_step
#       return self(x, training=False)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/engine/training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/engine/base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/engine/sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/engine/functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/engine/functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/engine/base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/layers/core/dense.py", line 255, in call
#       outputs = self.activation(outputs)
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/activations.py", line 317, in relu
#       return backend.relu(
#     File "/Users/katherinehuang/opt/anaconda3/envs/tensyflow/lib/python3.8/site-packages/keras/backend.py", line 5366, in relu
#       x = tf.nn.relu(x)
# Node: 'sequential/dense_2/Relu'
# In[0] and In[1] has different ndims: [11] vs. [10,1000]
# 	 [[{{node sequential/dense_2/Relu}}]] [Op:__inference_predict_function_21029]
